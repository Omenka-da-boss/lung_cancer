# %% [markdown]
# ## Exploratory Data Analysis Of Lung Cancer Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def lol():
    okay = 0
    wow = 2
    ond = 1
    test = 3
    
    return okay,wow,ond,test

okay = lol()

print(okay)
# Out:
# (0, 2, 1, 3)

# %%
df = pd.read_csv("lung_cancer_dataset.csv")

df.head()
# Out:
#    patient_id  age  gender  pack_years radon_exposure asbestos_exposure  \
# 0      100000   69    Male   66.025244           High                No
# 1      100001   32  Female   12.780800           High                No
# 2      100002   89  Female    0.408278         Medium               Yes
# 3      100003   78  Female   44.065232            Low                No
# 4      100004   38  Female   44.432440         Medium               Yes
#
#   secondhand_smoke_exposure copd_diagnosis alcohol_consumption family_history  \
# 0                        No            Yes            Moderate             No
# 1                       Yes            Yes            Moderate            Yes
# 2                       Yes            Yes                 NaN             No
# 3                       Yes             No            Moderate             No
# 4                        No            Yes                 NaN            Yes
#
#   lung_cancer
# 0          No
# 1         Yes
# 2         Yes
# ...

# %%
df.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'pack_years', 'radon_exposure',
#        'asbestos_exposure', 'secondhand_smoke_exposure', 'copd_diagnosis',
#        'alcohol_consumption', 'family_history', 'lung_cancer'],
#       dtype='object')

# %%
okay = df.isnull().sum()

# wow = enumerate(okay)
wow = dict(okay)

# for c,d in wow.items():
#     if d > 0:
#         df[c] = df[c].fillna("Unknown")

for c,d in wow.items():
        if df[c].dtype == "object":
            print("True")
            if d > 0:
                print("False")
                df[c] = df[c].fillna("Unknown")
# Out:
# True
# True
# True
# True
# True
# True
# False
# True
# True

# %%
bool_cols = [c for c in df.select_dtypes(include='bool').columns]
bool_cols
# Out:
# []

# %%
df['lung_cancer'].value_counts()
# Out:
# lung_cancer
# Yes    34364
# No     15636
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   patient_id                 50000 non-null  int64
#  1   age                        50000 non-null  int64
#  2   gender                     50000 non-null  object
#  3   pack_years                 50000 non-null  float64
#  4   radon_exposure             50000 non-null  object
#  5   asbestos_exposure          50000 non-null  object
#  6   secondhand_smoke_exposure  50000 non-null  object
#  7   copd_diagnosis             50000 non-null  object
#  8   alcohol_consumption        50000 non-null  object
#  9   family_history             50000 non-null  object
#  10  lung_cancer                50000 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 4.2+ MB

# %%
df.describe(include="all")
# Out:
#            patient_id           age  gender    pack_years radon_exposure  \
# count    50000.000000  50000.000000   50000  50000.000000          50000
# unique            NaN           NaN       2           NaN              3
# top               NaN           NaN  Female           NaN            Low
# freq              NaN           NaN   25085           NaN          16682
# mean    124999.500000     58.857040     NaN     49.963424            NaN
# std      14433.901067     23.958266     NaN     28.852082            NaN
# min     100000.000000     18.000000     NaN      0.002753            NaN
# 25%     112499.750000     38.000000     NaN     24.774558            NaN
# 50%     124999.500000     59.000000     NaN     50.177634            NaN
# 75%     137499.250000     80.000000     NaN     75.066740            NaN
# max     149999.000000    100.000000     NaN     99.999204            NaN
#
#        asbestos_exposure secondhand_smoke_exposure copd_diagnosis  \
# ...

# %%
df.isnull().sum()
# Out:
# patient_id                   0
# age                          0
# gender                       0
# pack_years                   0
# radon_exposure               0
# asbestos_exposure            0
# secondhand_smoke_exposure    0
# copd_diagnosis               0
# alcohol_consumption          0
# family_history               0
# lung_cancer                  0
# dtype: int64

# %%
df['alcohol_consumption'].value_counts()
# Out:
# alcohol_consumption
# Heavy       16762
# Unknown     16662
# Moderate    16576
# Name: count, dtype: int64

# %%
df[df['alcohol_consumption'].isna()]
# Out:
# Empty DataFrame
# Columns: [patient_id, age, gender, pack_years, radon_exposure, asbestos_exposure, secondhand_smoke_exposure, copd_diagnosis, alcohol_consumption, family_history, lung_cancer]
# Index: []

# %%
df['alcohol_consumption'] = df['alcohol_consumption'].fillna("Unknown")

# %%
df.dtypes
# Out:
# patient_id                     int64
# age                            int64
# gender                        object
# pack_years                   float64
# radon_exposure                object
# asbestos_exposure             object
# secondhand_smoke_exposure     object
# copd_diagnosis                object
# alcohol_consumption           object
# family_history                object
# lung_cancer                   object
# dtype: object

# %%
df['gender'] = df['gender'].map({"Male":1,"Female":0}).astype(int)
df['pack_years'] = round(df['pack_years'],2)

# %%
obj_cols = [c for c in df.select_dtypes(include="object").columns]

obj_cols
# Out:
# ['radon_exposure',
#  'asbestos_exposure',
#  'secondhand_smoke_exposure',
#  'copd_diagnosis',
#  'alcohol_consumption',
#  'family_history',
#  'lung_cancer']

# %%
lol = set(df['alcohol_consumption'].values)

lol
# Out:
# {'Heavy', 'Moderate', 'Unknown'}

# %%
bin_cols = [c for c in obj_cols if df[c].dropna().nunique() == 2]

bin_cols
# Out:
# ['asbestos_exposure',
#  'secondhand_smoke_exposure',
#  'copd_diagnosis',
#  'family_history',
#  'lung_cancer']

# %%
df['alcohol_consumption'].value_counts()
# Out:
# alcohol_consumption
# Heavy       16762
# Unknown     16662
# Moderate    16576
# Name: count, dtype: int64

# %%
bin_cols
# Out:
# ['asbestos_exposure',
#  'secondhand_smoke_exposure',
#  'copd_diagnosis',
#  'family_history',
#  'lung_cancer']

# %%
df[bin_cols] = df[bin_cols].replace({"Yes":1,"No":0})
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10016\3071230458.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[bin_cols] = df[bin_cols].replace({"Yes":1,"No":0})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   patient_id                 50000 non-null  int64
#  1   age                        50000 non-null  int64
#  2   gender                     50000 non-null  int32
#  3   pack_years                 50000 non-null  float64
#  4   radon_exposure             50000 non-null  object
#  5   asbestos_exposure          50000 non-null  int64
#  6   secondhand_smoke_exposure  50000 non-null  int64
#  7   copd_diagnosis             50000 non-null  int64
#  8   alcohol_consumption        50000 non-null  object
#  9   family_history             50000 non-null  int64
#  10  lung_cancer                50000 non-null  int64
# dtypes: float64(1), int32(1), int64(7), object(2)
# memory usage: 4.0+ MB

# %%
multi_cols = [c for c in  df.select_dtypes(include="object").columns]

# %%
multi_cols
# Out:
# ['radon_exposure', 'alcohol_consumption']

# %%
from sklearn.preprocessing import LabelEncoder

encode = LabelEncoder()

# %%
for c in multi_cols:
    df[c] = encode.fit_transform(df[c])

# %%
bool_cols = [c for c in df.select_dtypes(include="bool").columns]
bool_cols
# Out:
# []

# %%
df[bool_cols] = df[bool_cols].astype(int)

# %%
df.head()
# Out:
#    patient_id  age  gender  pack_years  radon_exposure  asbestos_exposure  \
# 0      100000   69       1       66.03               0                  0
# 1      100001   32       0       12.78               0                  0
# 2      100002   89       0        0.41               2                  1
# 3      100003   78       0       44.07               1                  0
# 4      100004   38       0       44.43               2                  1
#
#    secondhand_smoke_exposure  copd_diagnosis  alcohol_consumption  \
# 0                          0               1                    1
# 1                          1               1                    1
# 2                          1               1                    2
# 3                          1               0                    1
# 4                          0               1                    2
#
#    family_history  lung_cancer
# 0               0            0
# 1               1            1
# ...

# %%
df['alcohol_consumption'].value_counts()
# Out:
# alcohol_consumption
# 0    16762
# 2    16662
# 1    16576
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'pack_years', 'radon_exposure',
#        'asbestos_exposure', 'secondhand_smoke_exposure', 'copd_diagnosis',
#        'alcohol_consumption', 'family_history', 'lung_cancer'],
#       dtype='object')

# %%
df_corr = df.corr()

df_corr
# Out:
#                            patient_id       age    gender  pack_years  \
# patient_id                   1.000000 -0.004366 -0.007775   -0.000676
# age                         -0.004366  1.000000 -0.001576    0.003417
# gender                      -0.007775 -0.001576  1.000000    0.005559
# pack_years                  -0.000676  0.003417  0.005559    1.000000
# radon_exposure               0.003172 -0.004304  0.000248   -0.008731
# asbestos_exposure            0.010800 -0.002991 -0.004661    0.000581
# secondhand_smoke_exposure    0.003087 -0.004819 -0.004151    0.002442
# copd_diagnosis               0.003593 -0.000353 -0.003231    0.002318
# alcohol_consumption         -0.001116 -0.002387 -0.000889   -0.008434
# family_history              -0.006336 -0.005098  0.007358    0.002778
# lung_cancer                  0.002812  0.120938  0.000122    0.210301
#
#                            radon_exposure  asbestos_exposure  \
# patient_id                       0.003172           0.010800
# ...

# %%
# Run VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd
import numpy as np

# Prepare X
X = df.drop(columns=['lung_cancer'])
bool_cols = X.select_dtypes(include='bool').columns
X[bool_cols] = X[bool_cols].astype(int)

# Remove rows with missing or infinite values
X = X.replace([np.inf, -np.inf], np.nan)
X = X.dropna()

vif_data = pd.DataFrame()
vif_data['feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif_data = vif_data.sort_values(by='VIF', ascending=False)

print(vif_data)
# Out:
#                      feature        VIF
# 0                 patient_id  14.826443
# 1                        age   6.560373
# 3                 pack_years   3.870515
# 4             radon_exposure   2.462547
# 8        alcohol_consumption   2.447751
# 7             copd_diagnosis   1.984948
# 6  secondhand_smoke_exposure   1.983833
# 9             family_history   1.975462
# 5          asbestos_exposure   1.970518
# 2                     gender   1.969478

# %%
df = df.drop(["patient_id"],axis=1)

# %%
x = df.drop(['lung_cancer'],axis=1)
y = df['lung_cancer']

# %%
y.value_counts()
# Out:
# lung_cancer
# 1    34364
# 0    15636
# Name: count, dtype: int64

# %%
lol = (y.values == 1).sum()

lol
# Out:
# 34364

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y_train
# Out:
# 39087    1
# 30893    1
# 45278    0
# 16398    0
# 13653    1
#         ..
# 11284    1
# 44732    1
# 38158    0
# 860      0
# 15795    1
# Name: lung_cancer, Length: 40000, dtype: int64

# %%
# from xgboost import XGBClassifier
# from sklearn.metrics import accuracy_score,recall_score

# # from imblearn.over_sampling import SMOTE

# # smote = SMOTE()

# # x_train_s,y_train_s = smote.fit_resample(x_train,y_train)

# scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()

# # model = XGBClassifier(n_estimators=300,learning_rate=0.4,subsample=0.5,max_depth=5,random_state=12) acc = 70.8 rec = 84
# # model = XGBClassifier(n_estimators=200,learning_rate=0.7,subsample=0.7,max_depth=3,random_state=12) acc = 73.2 rec = 87.58
# model = XGBClassifier(n_estimators=120,learning_rate=1,subsample=1,max_depth=1,random_state=20)

# model.fit(x_train,y_train)

# pred = model.predict(x_test)

# acc = accuracy_score(y_test,pred)
# rec = recall_score(y_test,pred)

# print("Accuracy",acc)
# print("Recall",rec)


# # 1. ligthbm 2. lgr 3. knn m. lgr

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
import math

# okay = math.sqrt(len(y_test))
# okay = int(okay)

# base_model = []



# meta_learner = LogisticRegression()

# from imblearn.pipeline import Pipeline
# from sklearn.model_selection import StratifiedKFold,cross_validate
# from imblearn.over_sampling import SMOTE

# smote = SMOTE(sampling_strategy=0.6,random_state=42)

# stacked = StackingClassifier(base_model,meta_learner,passthrough=True,cv=5)

# skf = StratifiedKFold(n_splits=5,shuffle=True,random_state=42)

# pipeline = Pipeline([
#     ("smote",smote),("model",stacked)
# ])
# scoring = {
#     "recall":"recall",
#     "precision":"precision",
#     "f1":"f1",
#     "roc_auc":"roc_auc",
#     "accuracy":"accuracy"
# }
# results = cross_validate(pipeline,x,y,cv=skf,scoring=scoring,return_train_score=False)

# print(results)

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,StackingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,recall_score

base_model = [
    ('xgb', XGBClassifier(n_estimators=200,learning_rate=0.8,subsample=0.8,max_depth=3,random_state=12)),
    ('rf', RandomForestClassifier(class_weight='balanced_subsample',max_depth=3,criterion='entropy',random_state=12))
]

# class_weight='balanced', n_estimators=200
# 

meta_learner = DecisionTreeClassifier(criterion='entropy',max_depth=5,random_state=12)

stacked_model = StackingClassifier(estimators=base_model,final_estimator=meta_learner,passthrough=True,cv=5)


stacked_model.fit(x_train,y_train)

preds = stacked_model.predict(x_test)

acc = accuracy_score(y_test,preds)
rec = recall_score(y_test,preds)

print("Accuracy",acc)
print("Recall Score",rec)
# Out:
# Accuracy 0.7382
# Recall Score 0.9051147922115664

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score


# model = SVC(kernel='sigmoid',random_state=42)

# model.fit(x_train,y_train)

# preds = model.predict(x_test)

# acc = accuracy_score(y_test,preds)

# print(f"{acc * 100:.2f}")

# %%
# from sklearn.metrics import accuracy_score,recall_score,precision_score

# scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()

# xgb_params = {
#     "n_estimators": 800,
#     "learning_rate": 0.05,
#     "max_depth": 6,
#     "subsample": 0.8,
#     "colsample_bytree": 0.8,
#     "min_child_weight": 1,
#     "gamma": 0,
#     "reg_alpha": 0,
#     "reg_lambda": 1,
#     "scale_pos_weight": scale_pos_weight,
#     "objective": "binary:logistic",
#     "eval_metric": "aucpr"
# }


# model = XGBClassifier(**xgb_params)
# # model = GaussianNB()
# # model = GradientBoostingClassifier(n_estimators=200,learning_rate=0.9)
# # model = RandomForestClassifier(n_estimators=120)
# # model = LogisticRegression()
# # model = DecisionTreeClassifier()

# model.fit(x_train,y_train)

# pred = model.predict(x_test)

# acc = accuracy_score(y_test,pred)
# rec = recall_score(y_test,pred)
# pre = precision_score(y_test,pred)

# print(f"\nAccuracy:{acc}\n Recall:{rec} \n Precision:{pre}")

# %%
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.metrics import accuracy_score, recall_score

# # 1. Initialize model with improved parameters
# # model = GradientBoostingClassifier(
# #     n_estimators=1000,        # More trees = better learning
# #     learning_rate=0.01,       # Smaller = better accuracy
# #     max_depth=5,              # Control tree complexity
# #     subsample=0.8,            # Prevent overfitting
# #     min_samples_split=5,
# #     min_samples_leaf=2,
# #     max_features='sqrt',      # Good generalization
# #     random_state=42,
# #     criterion='friedman_mse'
# # )
# model = GradientBoostingClassifier(
#     n_estimators=800,
#     learning_rate=0.03,
#     max_depth=5,
#     subsample=0.8,
#     min_samples_split=10,
#     min_samples_leaf=4,
#     max_features='sqrt',
#     random_state=42
# )

# model.fit(x_train, y_train)

# # 2. Get probabilities instead of hard predictions
# probs = model.predict_proba(x_test)[:, 1]

# # 3. Use a custom threshold to ensure Recall >= 90%
# # Lowering the threshold (e.g., to 0.4) makes the model more 
# # "sensitive," boosting recall to meet your 90% target.
# threshold = 0.30 
# custom_preds = (probs >= threshold).astype(int)

# print(f"New Accuracy: {accuracy_score(y_test, custom_preds):.2%}")
# print(f"New Recall: {recall_score(y_test, custom_preds):.2%}")

# %%
# import optuna
# from sklearn.model_selection import StratifiedKFold
# from sklearn.metrics import accuracy_score, recall_score
# from xgboost import XGBClassifier


# skf = StratifiedKFold(
#     n_splits=5,
#     shuffle=True,
#     random_state=42
# )

# # the above splits the df in to 5 parts 


# def objective(trial):

#     params = {
#         "n_estimators": trial.suggest_int("n_estimators", 500, 2000),
#         "max_depth": trial.suggest_int("max_depth", 3, 8),
#         "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.05, log=True),
#         "subsample": trial.suggest_float("subsample", 0.7, 1.0),
#         "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 1.0),
#         "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
#         "gamma": trial.suggest_float("gamma", 0, 5),
#         "reg_alpha": trial.suggest_float("reg_alpha", 0, 5),
#         "reg_lambda": trial.suggest_float("reg_lambda", 1, 10),
#         "eval_metric": "logloss",
#         "random_state": 42,
#         "tree_method": "hist"
#     }

#     model = XGBClassifier(**params)

#     accuracies = []
#     recalls = []

#     # Cross Validation Loop
#     for train_idx, val_idx in skf.split(x_train, y_train):

#         X_t = x_train.iloc[train_idx]
#         X_v = x_train.iloc[val_idx]
#         y_t = y_train.iloc[train_idx]
#         y_v = y_train.iloc[val_idx]

#         model.fit(X_t, y_t, verbose=False)

#         preds = model.predict(X_v)

#         acc = accuracy_score(y_v, preds)
#         rec = recall_score(y_v, preds)

#         accuracies.append(acc)
#         recalls.append(rec)

#     mean_accuracy = np.mean(accuracies)
#     mean_recall = np.mean(recalls)

#     return mean_accuracy

# study = optuna.create_study(direction="maximize")

# study.optimize(objective, n_trials=30)

# print("Best Params:", study.best_params)
# print("Best Accuracy:", study.best_value)

# %%
# import optuna
# from xgboost import XGBClassifier
# from sklearn.metrics import recall_score
# from sklearn.model_selection import train_test_split

# # Objective function for Optuna
# def objective(trial):
#     params = {
#         "n_estimators": trial.suggest_int("n_estimators", 300, 1000),
#         "learning_rate": trial.suggest_float("learning_rate", 0.01, 1),
#         "max_depth": trial.suggest_int("max_depth", 0, 20),
#         "subsample": trial.suggest_float("subsample", 0.2, 1.0),
#         "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
#         "min_child_weight": trial.suggest_int("min_child_weight", 0, 20),
#         "gamma": trial.suggest_float("gamma", 0, 20),
#         "reg_alpha": trial.suggest_float("reg_alpha", 0, 20),
#         "reg_lambda": trial.suggest_float("reg_lambda", 0, 20),
#         "random_state": 42,
#         "n_jobs": -1,
#         "scale_pos_weight": (y_train == 0).sum() / (y_train == 1).sum(),
#         "eval_metric": "logloss"
#     }
    
#     THRESHOLD = 0.25
    
#     model = XGBClassifier(**params)
#     model.fit(x_train, y_train)
#     proba = model.predict_proba(x_test)[:, 1]
#     y_pred = (proba >= THRESHOLD).astype(int)  # Keep your tuned threshold
#     return recall_score(y_test, y_pred)  # Optimize recall for churners

# # Run Optuna
# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=30)

# print("Best Params:", study.best_params)
# print("Best Recall:", study.best_value)

# %%
# import mlflow 
# from mlflow import xgboost
# import os
# import time
# from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, roc_auc_score



# project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# mlflow.set_tracking_uri(f"file:\\{project_root}\\mlruns")
# mlflow.set_experiment("Lung Cancer Prediction")

# print(f"{project_root}\\mlops")

# with mlflow.start_run():
    
    
#     scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()
    
#     best_param = study.best_params
#     best_param.update({
#         "random_state": 42,
#         "n_jobs": -1,
#         "scale_pos_weight": scale_pos_weight,
#         "eval_metric": "logloss"
#     })
    
#     # Log Best Params
#     mlflow.log_params(best_param)
    
#     # Training Time
#     start_time = time.time()
#     model = XGBClassifier(**best_param)
#     model.fit(x_train,y_train)
#     end_time = time.time() - start_time
#     mlflow.log_metric("Train Time",end_time)
    
#     # Prediction Time
#     start_time = time.time()
#     preds = model.predict_proba(x_test)[:,1]
#     y_preds = (preds >= threshold).astype(int)
#     pred_time = time.time() - start_time
#     mlflow.log_metric("Prediction Time",pred_time)
    
#     # Metrices
#     precision = precision_score(y_test,y_preds,pos_label=1)
#     recall = recall_score(y_test,y_preds,pos_label=1)
#     f1 = f1_score(y_test,y_preds,pos_label=1)
#     roc_auc = roc_auc_score(y_test,y_preds)
#     acc = accuracy_score(y_test,y_preds)
    
#     # Log Metrics
#     mlflow.log_metric("Precision",precision)
#     mlflow.log_metric("Recall",recall)
#     mlflow.log_metric("F1 Score",f1)
#     mlflow.log_metric("Roc_Auc Score",roc_auc)
#     mlflow.log_metric("Accuracy Score",acc)
    
    
    
#     # Log Model
#     mlflow.xgboost.log_model(model, "model")
#     # mlflow.log_artifact(model,"model")
    
#     print(classification_report(y_test, y_preds, digits=3))
#     print(accuracy_score(y_test,y_preds))

# %%
# Best Params: {'n_estimators': 544, 'learning_rate': 0.01303542159960111, 'max_depth': 6, 'subsample': 0.2089364116529353, 'colsample_bytree': 0.3141691413686393, 'min_child_weight': 13, 'gamma': 9.97855315267791, 'reg_alpha': 6.284382889420716, 'reg_lambda': 2.280256119644983}
# Best Recall: 0.9155813953488372

# 'n_estimators': 921, 'learning_rate': 0.010141233290112493, 'max_depth': 18, 'subsample': 0.9260110876996337, 'colsample_bytree': 0.3331366778450362, 'min_child_weight': 10, 'gamma': 15.486429934763937, 'reg_alpha': 13.250730901707543, 'reg_lambda': 14.816379301546238 
# recall = 92.5 acc 74

# Best Params: {'n_estimators': 530, 'learning_rate': 0.013293655260583348, 'max_depth': 1, 'subsample': 0.6729696582773261, 'colsample_bytree': 0.8483286064745077, 'min_child_weight': 3, 'gamma': 14.277209352021318, 'reg_alpha': 6.285190578379433, 'reg_lambda': 4.03899548964789}
# Best Recall: 0.9196511627906977

# %%
# models = LGBMClassifier()

# models.fit(x_train,y_train)

# preds = models.predict(x_test)

# acc = accuracy_score(y_test,preds)
# rec = recall_score(y_test,preds)
# # pre = precision_score(y_test,preds)

# print(f"\nAccuracy:{acc}\n Recall:{rec}")

# %%
# from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score
# from sklearn.metrics import roc_auc_score
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.tree import DecisionTreeClassifier
# from xgboost import XGBClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.neighbors import KNeighborsClassifier
# import math as m

# okay = m.sqrt(len(y_test))
# okay = int(okay)

# model_dict = {"Logistic Regression":LogisticRegression(),
#               "SVC":SVC(kernel='rbf',random_state=0),
#               "Random Forest": RandomForestClassifier(),
#               "XG Boost": XGBClassifier(n_estimators=500,learning_rate=0.1,subsample=0.3,max_depth=10,random_state=1),
#               "Decision Tree": DecisionTreeClassifier(criterion='gini',random_state=42),
#               "GaussianNB": GaussianNB(),
#               "KNeighbors": KNeighborsClassifier(n_neighbors=okay)
#               }

# for name,model in model_dict.items():
#     print(f"----{name}----")
#     model.fit(x_train,y_train)
#     pred = model.predict(x_test)
#     print(f"\nThe accuracy score: {accuracy_score(y_test,pred)}")
#     print(f"\nThe Roc And Auc score: {roc_auc_score(y_test,pred)}")
#     print(f"\nThe precision score: {precision_score(y_test,pred)}")
#     print(f"\nThe recall score: {recall_score(y_test,pred)}")

# %%
# import lightgbm as lgb
# from sklearn.metrics import accuracy_score,recall_score
# import optuna
# from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,StackingClassifier
# from sklearn.linear_model import LogisticRegression
# from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
# from lightgbm import LGBMClassifier
# from sklearn.svm import SVC




# # from imblearn.over_sampling import SMOTE

# # smote = SMOTE()

# # x_train_s,y_train_s = smote.fit_resample(x_train,y_train)

# base_model = [
#    ("xgb",XGBClassifier(scale_pos_weight=3, learning_rate=0.05, n_estimators=200)),("catboost",CatBoostClassifier( iterations=1000, learning_rate=0.05,depth=6,loss_function="Logloss",auto_class_weights='Balanced',verbose=100))
# ]

# meta_learner = SVC(kernel='linear',random_state=42)

# stacked_model = StackingClassifier(estimators=base_model,final_estimator=meta_learner,passthrough=True,cv=5)


# stacked_model.fit(x_train,y_train)

# preds = stacked_model.predict(x_test)

# acc = accuracy_score(y_test,preds)
# rec = recall_score(y_test,preds)

# print("Accuracy",acc)
# print("Recall Score",rec)

# %%
THRESHOLD = 0.3
from sklearn.metrics import classification_report

# %%
# gnb = GaussianNB()

# gnb.fit(x_train,y_train)

# proba = gnb.predict_proba(x_test)[:,-1]
# pred = (proba >= THRESHOLD).astype(int)

# print(classification_report(y_test, pred, digits=3))

# %%
# lgr = LogisticRegression()

# lgr.fit(x_train,y_train)
# proba = lgr.predict_proba(x_test)[:,-1]
# pred = (proba >= THRESHOLD).astype(int)

# print(classification_report(y_test, pred, digits=3))

# %%
# from sklearn.metrics import precision_score, recall_score, f1_score

# proba = gnb.predict_proba(x_test)[:, 1]

# print("Threshold tuning for XGBoost")

# print(f"{'Thresh':<8}{'Prec_1':<8}{'Rec_1':<8}{'F1_1':<8}")
# for thresh in [0.25, 0.30, 0.35, 0.40, 0.45, 0.50]:
#     preds = (proba >= thresh).astype(int)
#     prec = precision_score(y_test, preds, pos_label=1)
#     rec = recall_score(y_test, preds, pos_label=1)
#     f1 = f1_score(y_test, preds, pos_label=1)
#     print(f"{thresh:<8}{prec:<8.3f}{rec:<8.3f}{f1:<8.3f}")

# %%
# import optuna
# from sklearn.naive_bayes import GaussianNB
# from sklearn.metrics import recall_score,precision_score
# from sklearn.model_selection import train_test_split

# def objective(trial):
#     params = {
#       "n_neighbors":trial.suggest_int("n_neighbors",3,50),
#       "weights":trial.suggest_categorical("weights",["uniform","distance"]),
#       "p":trial.suggest_int("p",1,2)
#     }
    
#     THRESHOLD = trial.suggest_float("THRESHOLD",0.1,0.9)

#     model = KNeighborsClassifier(**params)
#     model.fit(x_train, y_train)
#     proba = model.predict_proba(x_test)[:,1]
#     pred = (proba >= THRESHOLD).astype(int)
#     return accuracy_score(y_test,pred)


# study = optuna.create_study(direction="maximize")
# study.optimize(objective,n_trials=30)


# print("Best Params",study.best_params)
# print("Best Recall ",study.best_value)

# %%
# def objective(trial):
#     params = {
#         "iterations": trial.suggest_int("iterations", 500, 2000),
#         "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
#         "depth": trial.suggest_int("depth", 4, 10),
#         "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 20),
#         "random_strength": trial.suggest_float("random_strength", 0, 10),
#         "bagging_temperature": trial.suggest_float("bagging_temperature", 0, 1),
#         "loss_function": "Logloss",
#         "eval_metric": "AUC",
#         "auto_class_weights": "Balanced",
#         "verbose": 0,
#         "random_state": 42
#     }

#     model = CatBoostClassifier(**params)
#     model.fit(X_train, y_train)

#     proba = model.predict_proba(X_test)[:, 1]
#     return roc_auc_score(y_test, proba)

# %%
# knn =  KNeighborsClassifier(n_neighbors=okay,weights="uniform",p=1)

# knn.fit(x_train,y_train)

# pred = knn.predict(x_test)

# acc = accuracy_score(y_test,pred)

# acc

# %%
# import lightgbm as lgb
# from sklearn.metrics import accuracy_score,recall_score
# import optuna

# modelss = lgb.LGBMClassifier(
#     objective="binary",
#     metric="auc",
#     is_unbalance=True,
#     random_state=42
# )

# modelss.fit(x_train, y_train)
# pred = modelss.predict(x_test)

# acc = recall_score(y_test,pred)

# %%
# def objective(trial):
#     params = {
#         "objective": "binary",
#         "metric": "auc",
#         "boosting_type": "gbdt",
#         "n_estimators": trial.suggest_int("n_estimators", 500, 3000),
#         "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.2, log=True),

# #         "num_leaves": trial.suggest_int("num_leaves", 20, 150),
# #         "max_depth": trial.suggest_int("max_depth", 3, 12),
# #         "min_child_samples": trial.suggest_int("min_child_samples", 20, 200),
# #         "subsample": trial.suggest_float("subsample", 0.6, 1.0),
# #         "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
# #         "reg_alpha": trial.suggest_float("reg_alpha", 0, 10),
# #         "reg_lambda": trial.suggest_float("reg_lambda", 0, 10)
#         "is_unbalance": True,
#         "random_state": 42
#     }

#     model = lgb.LGBMClassifier(**params)
#     model.fit(x_train, y_train)

#     proba = model.predict_proba(x_test)[:, 1]
#     pred = (proba >= THRESHOLD).astype(int)
#     return accuracy_score(y_test, pred)



# study = optuna.create_study(direction="maximize")
# study.optimize(objective,n_trials=30)


# print("Best Params",study.best_params)
# print("Best Recall ",study.best_value)

# %%
# from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,StackingClassifier
# from sklearn.linear_model import LogisticRegression
# from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
# from sklearn.svm import SVC
# from sklearn.tree import DecisionTreeClassifier

# base_model = [
#     ('dtc', DecisionTreeClassifier(criterion='entropy',max_depth=5,random_state=12)),
#     ('rf', RandomForestClassifier(class_weight='balanced_subsample',max_depth=3,criterion='entropy',random_state=12))
# ]

# # class_weight='balanced', n_estimators=200
# # 

# meta_learner = XGBClassifier(n_estimators=200,learning_rate=0.8,subsample=0.8,max_depth=3,random_state=12)

# stacked_model = StackingClassifier(estimators=base_model,final_estimator=meta_learner,passthrough=True,cv=5)


# stacked_model.fit(x_train,y_train)

# preds = stacked_model.predict_proba(x_test)[:,1]
# pred = (preds >= 0.45).astype(int)

# acc = accuracy_score(y_test,pred)
# rec = recall_score(y_test,pred)

# print("Accuracy",acc)
# print("Recall Score",rec)

# %%
# import optuna
# from xgboost import XGBClassifier
# from sklearn.model_selection import cross_val_score
# from sklearn.metrics import recall_score
# from sklearn.ensemble import RandomForestClassifier,StackingClassifier
# from sklearn.tree import DecisionTreeClassifier

# def hyper_tuning(x_train,y_train,x_test,y_test,threshold,y):
    
#     def objective(trial):
        
#         xgb_params = {
#         "n_estimators": trial.suggest_int("n_estimators", 500, 2000),
#         "max_depth": trial.suggest_int("max_depth", 3, 8),
#         "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.05, log=True),
#         "subsample": trial.suggest_float("subsample", 0.7, 1.0),
#         "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 1.0),
#         "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
#         "gamma": trial.suggest_float("gamma", 0, 5),
#         "reg_alpha": trial.suggest_float("reg_alpha", 0, 5),
#         "reg_lambda": trial.suggest_float("reg_lambda", 1, 10),
#         "eval_metric": "logloss",
#         "random_state": 42,
#         "tree_method": "hist"
#     }
#         rbf_params = {
#         "n_estimators": 500,
#         "max_depth":  25,
#         "min_samples_split": 8,
#         "min_samples_leaf": 5,
#         "max_features":  "log2",
#         "bootstrap":  True,
#         "ccp_alpha": 1e-3,
#         "random_state": 42
#     }
#         params = {
#         "max_depth": 20,
#         "min_samples_split": 25,
#         "min_samples_leaf": 10,
#         "max_features": "sqrt",
#         "ccp_alpha":  1e-3,
#         "criterion":  "gini",
#         "random_state": 42
#     }

#         # model = DecisionTreeClassifier(**params)

#         # RandomForestClassifier(**params)
        
#         base_model = [
#             ("dtc",DecisionTreeClassifier(**params)),
#             ("rbf",RandomForestClassifier(**rbf_params))
#         ]
        
#         meta_learner =  XGBClassifier(**xgb_params)

#         model = StackingClassifier(estimators=base_model,final_estimator=meta_learner,passthrough=True,cv=3)
#         model.fit(x_train, y_train)
#         proba = model.predict_proba(x_test)[:, 1]
#         y_pred = (proba >= threshold).astype(int)  # Keep your tuned threshold
#         print(accuracy_score(y_test,y_pred))
#         return recall_score(y_test, y_pred)
    
    
#     study = optuna.create_study(direction="maximize")
#     study.optimize(objective,n_trials=10)
    
#     print("Best Parameters",study.best_params)
#     print("Best Recall:", study.best_value)
#     return study.best_params

# hyper_tuning(x_train,y_train,x_test,y_test,0.45,y)

# %%
# from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,StackingClassifier
# from sklearn.linear_model import LogisticRegression
# from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
# from sklearn.svm import SVC


# from imblearn.over_sampling import SMOTE

# smote = SMOTE()

# x_train_s,y_train_s = smote.fit_resample(x_train,y_train)

# base_model = [
#     ('xgb', XGBClassifier(scale_pos_weight=3, learning_rate=0.05, n_estimators=200)),
#     ('rf', RandomForestClassifier(class_weight='balanced', n_estimators=200))
# ]

# meta_learner = SVC(kernel='rbf',random_state=0)

# stacked_model = StackingClassifier(estimators=base_model,final_estimator=meta_learner,passthrough=True,cv=5)


# stacked_model.fit(x_train,y_train)

# preds = stacked_model.predict(x_test)

# acc = accuracy_score(y_test,preds)
# rec = recall_score(y_test,preds)

# print("Accuracy",acc)
# print("Recall Score",rec)


# # model = CatBoostClassifier( 
# #         iterations=1000, 
# #         learning_rate=0.05,
# #         depth=6,
# #         loss_function="Logloss",
# #         auto_class_weights='Balanced',
# #         verbose=100
# #     )

# # model.fit(x_train_s,y_train_s,cat_features=[0,1])

# # pred = model.predict(x_test)

# # acc = accuracy_score(y_test,pred)

# # print(acc)

# %%
# from sklearn.svm import SVC

# model = SVC(kernel='rbf',random_state=42)

# model.fit(x_train_s,y_train_s)

# pred = model.predict(x_test)

# acc = accuracy_score(y_test,pred)

# print(acc)

# %%
# y_train_s

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import optuna


def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "max_depth": trial.suggest_int("max_depth", 5, 40),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "ccp_alpha": trial.suggest_float("ccp_alpha", 1e-5, 1e-1, log=True),
        "n_jobs": -1,
        "random_state": 42
    }
    model = RandomForestClassifier(
        **params
    )

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    score = cross_val_score(
        model,
        x,
        y,
        cv=cv,
        scoring="accuracy"
    ).mean()

    return score


study = optuna.create_study(direction="maximize")

# Optimize
study.optimize(objective, n_trials=50)

print("Best Trial:")
print("Value (Accuracy):", study.best_value)
print("Params:", study.best_params)

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import recall_score
from sklearn.ensemble import RandomForestClassifier,StackingClassifier
from sklearn.tree import DecisionTreeClassifier

def hyper_tuning(x_train,y_train,x_test,y_test,threshold,y):
    
    def objective(trial):
        params = {
            "n_estimators": trial.suggest_int("n_estimators", 200, 800),
            "max_depth": trial.suggest_int("max_depth", 5, 40),
            "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
            "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
            "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
            "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
            "ccp_alpha": trial.suggest_float("ccp_alpha", 1e-5, 1e-1, log=True),
            "n_jobs": -1,
            "random_state": 42
        }

        model = RandomForestClassifier(**params)

        model.fit(x_train, y_train)

        proba = model.predict_proba(x_test)[:, 1]
        preds = (proba >= 0.45).astype(int)
        acc = accuracy_score(y_test,preds) * 100
        acc = round(acc,2)
        
        if acc >= 71:
            print("Accuracy Score:",acc)
            # return recall_score(y_test, preds)
            return recall_score(y_test,preds)
        else: 
            return "Too Low Accuracy"


    study = optuna.create_study(direction="maximize")
    study.optimize(objective,n_trials=10)
    return study.best_params


    print("Best Params",study.best_params)
    print("Best Recall ",study.best_value)

hyper_tuning(x_train,y_train,x_test,y_test,0.35,y)
# Out:
# [I 2026-02-22 14:47:48,708] A new study created in memory with name: no-name-a876384e-3910-4f19-b088-45decc24bb78
# [I 2026-02-22 14:48:31,013] Trial 0 finished with value: 0.9736995059575705 and parameters: {'n_estimators': 645, 'max_depth': 29, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': False, 'ccp_alpha': 0.002586085021168459}. Best is trial 0 with value: 0.9736995059575705.
# Accuracy Score: 72.52
# [W 2026-02-22 14:49:22,112] Trial 1 failed with parameters: {'n_estimators': 728, 'max_depth': 38, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'ccp_alpha': 0.021630588551549736} because of the following error: The value 'T' could not be cast to float.
# [W 2026-02-22 14:49:22,113] Trial 1 failed with value 'Too Low Accuracy'.
# ...

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import optuna

def objective(trial):
   
    # Hyperparameter search space
    params = {
        "criterion": trial.suggest_categorical("criterion", ["gini", "entropy", "log_loss"]),
        "max_depth": trial.suggest_int("max_depth", 2, 50),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 20),
        "max_features": trial.suggest_categorical("max_features", [None, "sqrt", "log2"]),
        "ccp_alpha": trial.suggest_float("ccp_alpha", 0.0, 0.05),
    }

    model = DecisionTreeClassifier(
        **params,
        random_state=42
    )

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    score = cross_val_score(
        model,
        x,
        y,
        cv=cv,
        scoring="recall"
    ).mean()

    return score

# Create study
study = optuna.create_study(direction="maximize")

# Optimize
study.optimize(objective, n_trials=50)

print("Best Trial:")
print("Value (Accuracy):", study.best_value)
print("Params:", study.best_params)

# %%
lol = {'criterion': 'log_loss', 'max_depth': 17, 'min_samples_split': 19, 'min_samples_leaf': 11, 'max_features': 'log2', 'ccp_alpha': 0.010101387197753353}

model = RandomForestClassifier(**lol)
model.fit(x_train,y_train)
preds = model.predict_proba(x_test)[:,1]
pred = (preds >= 0.30).astype(int)

acc = accuracy_score(y_test,pred)

print(acc)
# Out:
# 0.6882

# %%
# base_algorithms = [
#     ('cat', CatBoostClassifier(
#         cat_features=categorical_features, 
#         iterations=1000, 
#         learning_rate=0.05,
#         auto_class_weights='Balanced',
#         verbose=0
#     )),
#     ('xgb', XGBClassifier(
#         enable_categorical=True, # New feature in XGBoost
#         scale_pos_weight=3, 
#         n_estimators=200
#     ))
# ]

# # 4. Create the Meta-Learner (The "Decision Maker")
# meta_learner = LogisticRegression()

# # 5. Join them into a Stacking Model
# joined_model = StackingClassifier(
#     estimators=base_algorithms,
#     final_estimator=meta_learner,
#     cv=5
# )

# # 6. Build the final Pipeline with Resampling
# # This handles the 72% accuracy issue by balancing the 50k rows
# model_pipeline = Pipeline([
#     ('resample', SMOTE(random_state=42)),
#     ('stacking', joined_model)
# ])

# %%
# from xgb i
# Out:
#   Cell In[69], line 1
#     from xgb i
#              ^
# SyntaxError: invalid syntax

# %%
# import optuna
# from catboost import CatBoostClassifier
# from xgboost import XGBClassifier
# from sklearn.metrics import balanced_accuracy_score
# from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,StackingClassifier
# from sklearn.linear_model import LogisticRegression
# from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
# from lightgbm import LGBMClassifier

# def objective(trial):
#     # --- XGBoost Parameter Space ---
#     xgb_params = {
#         'n_estimators': trial.suggest_int('xgb_n_estimators', 100, 1000),
#         'max_depth': trial.suggest_int('xgb_max_depth', 3, 10),
#         'learning_rate': trial.suggest_float('xgb_lr', 0.01, 0.3, log=True),
#         'subsample': trial.suggest_float('xgb_subsample', 0.5, 1.0),
#         'colsample_bytree': trial.suggest_float('xgb_colsample', 0.5, 1.0),
#         'scale_pos_weight': trial.suggest_float('xgb_spw', 1, 10), # Crucial for your Recall
#         'enable_categorical': True
#     }
    
#     # --- CatBoost Parameter Space ---
#     cat_params = {
#         'iterations': trial.suggest_int('cat_iter', 100, 1000),
#         'depth': trial.suggest_int('cat_depth', 4, 10),
#         'learning_rate': trial.suggest_float('cat_lr', 0.01, 0.3, log=True),
#         'l2_leaf_reg': trial.suggest_float('cat_l2', 1e-3, 10.0, log=True),
#         'auto_class_weights': 'Balanced',
#         'verbose': 0
#     }
#     params = {
#         "objective": "binary",
#         "metric": "auc",
#         "boosting_type": "gbdt",
#         "n_estimators": trial.suggest_int("n_estimators", 500, 3000),
#         "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.2, log=True),
#         "num_leaves": trial.suggest_int("num_leaves", 20, 150),
#         "max_depth": trial.suggest_int("max_depth", 3, 12),
#         "min_child_samples": trial.suggest_int("min_child_samples", 20, 200),
#         "subsample": trial.suggest_float("subsample", 0.6, 1.0),
#         "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
#         "reg_alpha": trial.suggest_float("reg_alpha", 0, 10),
#         "reg_lambda": trial.suggest_float("reg_lambda", 0, 10),
#         "is_unbalance": True,
#         "random_state": 42
#     }

#     # Train and evaluate (Simplified for this example)
#     # In a real run, you would use Cross-Validation here
    
#     stacked = [("cat",CatBoostClassifier(**cat_params, cat_features=[0,1])),("lgb",LGBMClassifier(**params))]
    
#     meta_learner = XGBClassifier(**xgb_params)
    
    
    
#     model_cat = StackingClassifier(estimators=stacked,final_estimator=meta_learner,cv=5)
#     model_cat.fit(x_train, y_train)
#     preds = model_cat.predict(x_test)
    
#     # We return the metric we want to MAXIMIZE (Balanced Accuracy is best for you)
#     return balanced_accuracy_score(y_test, preds)

# # 2. Run the Study
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=30) # Run 50 experiments

# print("Best Parameters:", study.best_params)
# Out:
# [I 2026-02-01 21:18:31,011] A new study created in memory with name: no-name-243d64ef-5621-4659-9bad-9a118df4cf07
# [I 2026-02-01 21:22:02,020] Trial 0 finished with value: 0.5351371496720334 and parameters: {'xgb_n_estimators': 299, 'xgb_max_depth': 9, 'xgb_lr': 0.06830301430000747, 'xgb_subsample': 0.5877702849466668, 'xgb_colsample': 0.5562240343941336, 'xgb_spw': 3.5370619738971647, 'cat_iter': 449, 'cat_depth': 4, 'cat_lr': 0.21857697394295147, 'cat_l2': 0.014921947161240852, 'n_estimators': 2949, 'learning_rate': 0.034097039976045324, 'num_leaves': 119, 'max_depth': 5, 'min_child_samples': 112, 'subsample': 0.9537758541353538, 'colsample_bytree': 0.9114455845157224, 'reg_alpha': 4.0939669371441765, 'reg_lambda': 6.740047534922491}. Best is trial 0 with value: 0.5351371496720334.
# ...

# %%
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score,recall_score
import numpy as np
import optuna

def objective(trial):
    # 1. Define the Hyperparameters for CatBoost
    param = {
        "iterations": trial.suggest_int("iterations", 100, 1500),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "depth": trial.suggest_int("depth", 4, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-2, 20.0),
        "random_strength": trial.suggest_float("random_strength", 1e-2, 10.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "verbose": False,
        "allow_writing_files": False
    }

    # 2. SMOTE the training data ONLY
    # This ensures your validation set remains representative of real-world data
    # sm = SMOTE(random_state=42)
    # X_train_res, y_train_res = sm.fit_resample(x_train, y_train)

    # 3. Initialize and Train Model
    from catboost import CatBoostClassifier
    model = CatBoostClassifier(**param)
    model.fit(x_train, y_train)

    # 4. FIX: Use .predict() instead of .predict_proba()
    # predict() returns integers (0, 1), which accuracy_score requires.
    preds = model.predict(x_test)
    
    # Ensure targets are integers (SMOTE sometimes casts to float)
    return accuracy_score(y_test, preds)

# Run the study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=10)



# print("Accuracy:", accuracy_score(y_test, preds))
# print("Recall:", recall_score(y_test, preds))
# Out:
# [I 2026-02-01 20:46:16,492] A new study created in memory with name: no-name-0b3adfb9-1fb9-4074-a83a-b0ac5f25f65a
# [I 2026-02-01 20:46:54,851] Trial 0 finished with value: 0.70656 and parameters: {'iterations': 1081, 'learning_rate': 0.18903286349623963, 'depth': 9, 'l2_leaf_reg': 9.259207713945342, 'random_strength': 3.355239431006164, 'bagging_temperature': 0.5657461561829499}. Best is trial 0 with value: 0.70656.
# [I 2026-02-01 20:47:09,433] Trial 1 finished with value: 0.73848 and parameters: {'iterations': 795, 'learning_rate': 0.0029245622576370505, 'depth': 6, 'l2_leaf_reg': 19.921080029926166, 'random_strength': 2.8435848987911494, 'bagging_temperature': 0.1624451832223055}. Best is trial 1 with value: 0.73848.
# ...

# %%
# from sklearn.metrics import recall_score, accuracy_score
# import numpy as np

# best_model = LGBMClassifier(**best_params, class_weight="balanced", random_state=42)

# pipeline = Pipeline([
#     ("preprocess", preprocessor),
#     ("model", best_model)
# ])

# pipeline.fit(X_train, y_train)

# probs = pipeline.predict_proba(X_test)[:, 1]

# # Lower threshold to boost recall
# threshold = 0.35
# preds = (probs >= threshold).astype(int)

# print("Accuracy:", accuracy_score(y_test, preds))
# print("Recall:", recall_score(y_test, preds))

# %%
# import optuna
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
# from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# from sklearn.metrics import recall_score, accuracy_score
# from lightgbm import LGBMClassifier

# # Load data
# df = pd.read_csv("lung_cancer_dataset.csv")

# X = df.drop(columns=["lung_cancer", "patient_id"])
# y = df["lung_cancer"].map({"No": 0, "Yes": 1})

# # Train-test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.2, stratify=y, random_state=42
# )

# # Column types
# num_features = ["age", "pack_years"]
# cat_features = [col for col in X.columns if col not in num_features]

# # Preprocessing
# preprocessor = ColumnTransformer(
#     transformers=[
#         ("num", StandardScaler(), num_features),
#         ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
#     ]
# )

# # Optuna objective
# def objective(trial):
#     model = LGBMClassifier(
#         n_estimators=trial.suggest_int("n_estimators", 1200, 1600),
#         learning_rate=trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
#         max_depth=trial.suggest_int("max_depth", 3, 12),
#         num_leaves=trial.suggest_int("num_leaves", 16, 128),
#         min_child_samples=trial.suggest_int("min_child_samples", 10, 100),
#         subsample=trial.suggest_float("subsample", 0.6, 1.0),
#         colsample_bytree=trial.suggest_float("colsample_bytree", 0.6, 1.0),
#         class_weight="balanced",
#         random_state=42
#     )

#     pipeline = Pipeline([
#         ("preprocess", preprocessor),
#         ("model", model)
#     ])

#     pipeline.fit(X_train, y_train)
#     preds = pipeline.predict(X_test)

#     return recall_score(y_test, preds)

# # Run optimization
# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=30)

# best_params = study.best_params
# print("Best Params:", best_params)
